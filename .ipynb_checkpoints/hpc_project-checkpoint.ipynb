# %%
import datetime
import math
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
from datetime import timedelta

# %%
eeg_recording = pd.read_csv('../Sleep Data/raw_data_1/101/PSG_raw/C3.txt', sep=' ', skiprows=7, header=None)
eeg_recording.columns = ['data']

# %%
eeg_numpy = np.array(eeg_recording['data'])

# %%
eeg_numpy = eeg_numpy[:-128]

# %%
allData = np.array(np.split(eeg_numpy, len(eeg_numpy)/(128*30)))

# %%
num_inputs = 2
num_filters = 100

fig, axes = plt.subplots(num_inputs, figsize=(30,20))

for i in range(0, num_inputs):
    axes[i].plot(allData[i])
    axes[i].set_title('Input: ' + str(i + 1))
    
    item = []
    
    for j in range(0, num_filters):
        y = gaussian_filter(allData[i], j + 1)
        axes[i].plot(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-615ebb2b0757> in <module>
#      11
#      12     for j in range(0, num_filters):
# ---> 13         y = gaussian_filter(allData[i], j + 1)
#      14         axes[i].plot(y)
#
# NameError: name 'gaussian_filter' is not defined

# %%
from scipy.ndimage import gaussian_filter1d

encoded_items = []

def encode_data(index, num_threads, num_filters = 100):
    
    l = threading.Lock()
    
    last = 0
    
    if index == num_threads - 1: last = 1
    
    start = index * int(len(allData)/num_threads)
    end =  last + (index + 1) * int(len(allData)/num_threads)
    
    print("Start: " +  str(start))
    print("End: " +  str(end))
        
    for data in allData[start:end]:
        item = []        
        for i in range(num_filters):
            y = gaussian_filter1d(data, i + 1)
            item.append(y)
        with l:    
            encoded_items.append(item)
           
    print("Thread: ", index)

# %%
import threading
import time

if __name__ == "__main__":
    
    num_threads = 3
    
    threads = list()
    for index in range(num_threads):
        print("Main    : create and start thread ", index)        
        x = threading.Thread(target=encode_data, args=(index,num_threads))
        threads.append(x)
        x.start()
        
    for index, thread in enumerate(threads):
        print("Main    : before joining thread %d.", index)
        thread.join()
        print("Main    : thread %d done", index)
# Out:
# Main    : create and start thread  0
# Start: 0Main    : create and start thread  1
# Start: 273
# End: 546
#
# End: 273Main    : create and start thread  2
#
# Start: 546Main    : before joining thread %d. 0
#
# End: 820
# Thread:  1
# Thread:  2
# Thread:  0
# Main    : thread %d done 0
# Main    : before joining thread %d. 1
# Main    : thread %d done 1
# Main    : before joining thread %d. 2
# Main    : thread %d done 2

# %%
len(encoded_items)
# Out:
# 820

# %%
len(allData)
# Out:
# 820
