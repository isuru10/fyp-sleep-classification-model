# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# %%
mat = scipy.io.loadmat('../ISRUC-Sleep Dataset/Subgroup 3/Subject 1/subject1.mat')

# %%
labels = np.loadtxt('../ISRUC-Sleep Dataset/Subgroup 3/Subject 1/1/1_1.txt')[:-30]

# %%
np.place(labels, labels==5, [4])

# %%
data = np.array(mat['C3_A2'])

# %%
unique, counts = np.unique(labels, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 162, 1.0: 114, 2.0: 369, 3.0: 178, 4.0: 101}

# %%
from modwt import modwt, modwtmra

ET = []

WT = []

for element in data:
    wt = modwt(element, 'db4', 6)
    WT.append(wt)
    E = []
    for w in wt:
        E.append(np.sum(np.abs(w) ** 2))
    ET.append(E)

# %%
PET = []

for E in ET:
    PE = []
    for element in E:
        PE.append(element/np.sum(E))
    PET.append(PE)

# %%
MT = []

for W in WT:
    M = []
    for element in W:        
        M.append(np.mean(w))
    MT.append(M)

# %%
StdT = []

for W in WT:
    Std = []
    for element in W:        
        Std.append(np.std(w))
    StdT.append(Std)

# %%
PT = []

for element in data:
    PT.append(np.max(element) - np.min(element))

# %%
# E0 = np.sum(np.abs(wt[0]) ** 2)
# E1 = np.sum(np.abs(wt[1]) ** 2)
# E2 = np.sum(np.abs(wt[2]) ** 2)
# E3 = np.sum(np.abs(wt[3]) ** 2)
# E4 = np.sum(np.abs(wt[4]) ** 2)
# E5 = np.sum(np.abs(wt[5]) ** 2)

# %%
# PE0 = E0 / (E0 + E1 + E2 + E3 + E4 + E5)
# PE1 = E1 / (E0 + E1 + E2 + E3 + E4 + E5)
# PE2 = E2 / (E0 + E1 + E2 + E3 + E4 + E5)
# PE3 = E3 / (E0 + E1 + E2 + E3 + E4 + E5)
# PE4 = E4 / (E0 + E1 + E2 + E3 + E4 + E5)
# PE5 = E5 / (E0 + E1 + E2 + E3 + E4 + E5)

# %%
# M0 = np.mean(wt[0])
# M1 = np.mean(wt[1])
# M2 = np.mean(wt[2])
# M3 = np.mean(wt[3])
# M4 = np.mean(wt[4])
# M5 = np.mean(wt[5])

# %%
# Std0 = np.std(wt[0])
# Std1 = np.std(wt[1])
# Std2 = np.std(wt[2])
# Std3 = np.std(wt[3])
# Std4 = np.std(wt[4])
# Std5 = np.std(wt[5])

# %%
# P0 = np.max(data[0]) - np.min(data[0])

# %%
print('ET: ', len(ET))
print('PET: ', len(PET))
print('MT: ', len(MT))
print('StdT: ', len(StdT))
print('PT: ', len(PT))
# Out:
# ET:  924
# PET:  924
# MT:  924
# StdT:  924
# PT:  924

# %%
data_new = []

ET_np = np.array(ET)
PET_np = np.array(PET)
MT_np = np.array(MT)
StdT_np = np.array(StdT)
PT_np = np.array(PT)


for i in range(len(data)):
    element = []
    element.append(data[i])
    element.append(ET_np[i])
    element.append(PET_np[i])
    element.append(MT_np[i])
    element.append(StdT_np[i])
    element.append(PT_np[i])
    print(np.array(element).shape)
    data_new.append(element)
# Out:
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)
# (6,)

# %%
data_new = np.array(data_new)

# %%
WT_np = np.array(WT)

# %%
data.shape
# Out:
# (924, 6000)

# %%
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Conv1D, Conv2D, MaxPooling1D, MaxPooling2D
from tensorflow.keras import Input

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
data_p = preprocessing.scale(data)

# %%
ET_np_p.shape

# %%
ET_np_p = np.reshape(ET_np_p, (ET_np_p.shape[0], 1, ET_np_p.shape[1]))

# %%
import random

random.shuffle(ET_np_p)

# %%
ET_np_p.shape

# %%
train_data, test_data, train_labels, test_labels = train_test_split(data_p, labels, test_size=0.33, random_state=42)

# %%
# train_data = ET_np_p[:691]
# test_data = ET_np_p[691:]

# train_labels = labels[:691]
# test_labels = labels[691:]

# %%
train_data.shape
# Out:
# (619, 6000)

# %%
# Embedding
max_features = 30000
maxlen = 7
# input_shape = [7,6000]
embedding_size = 128

# Convolution
kernel_size = 4
filters = 64
pool_size = 2

# LSTM
lstm_output_size = 14

# Training
batch_size = 20
epochs = 15

# %%
# model = Sequential()
# # model.add(Embedding(max_features, embedding_size, input_length=maxlen))
# # model.add(Dropout(0.25))
# # model.add(Conv1D(filters,
# #                  kernel_size,
# #                  padding='valid',
# #                  activation='relu',
# #                  strides=2))
# # model.add(MaxPooling1D(pool_size=pool_size))

# # model.add(LSTM(units=64,
# #                input_shape=(1,7), return_sequences = True, batch_size = batch_size, stateful=True))
# # model.add(LSTM(units=64, activation='relu',
# #                input_shape=(1,7), batch_size = batch_size, stateful=True))
# model.add(LSTM(units=256, activation='relu', input_shape=(1,7)))
# # model.add(Dropout(0.25))
# # model.add(LSTM(units=512, activation='relu'))
# model.add(Dense(5, activation='relu'))
# model.add(Activation('softmax'))

# %%
model = Sequential()
model.add(Dense(1024, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(train_data, train_labels,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(test_data, test_labels))
# Out:
# Train on 619 samples, validate on 305 samples
# Epoch 1/15
# 619/619 [==============================] - 4s 6ms/sample - loss: 2.2170 - acc: 0.3005 - val_loss: 1.5232 - val_acc: 0.4000
# Epoch 2/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 1.3361 - acc: 0.4604 - val_loss: 2.0438 - val_acc: 0.3770
# Epoch 3/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.9846 - acc: 0.6074 - val_loss: 2.0761 - val_acc: 0.2393
# Epoch 4/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.7903 - acc: 0.7771 - val_loss: 2.1512 - val_acc: 0.3344
# Epoch 5/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.5437 - acc: 0.8417 - val_loss: 3.3810 - val_acc: 0.2852
# Epoch 6/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.3949 - acc: 0.9095 - val_loss: 3.8145 - val_acc: 0.2820
# Epoch 7/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.2529 - acc: 0.9305 - val_loss: 4.4258 - val_acc: 0.3016
# Epoch 8/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.5735 - acc: 0.9111 - val_loss: 3.4388 - val_acc: 0.2787
# Epoch 9/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.2779 - acc: 0.9321 - val_loss: 5.9638 - val_acc: 0.2590
# Epoch 10/15
# 619/619 [==============================] - 2s 4ms/sample - loss: 0.2464 - acc: 0.9645 - val_loss: 4.2878 - val_acc: 0.3180
# Epoch 11/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.1612 - acc: 0.9532 - val_loss: 6.2884 - val_acc: 0.3279
# Epoch 12/15
# 619/619 [==============================] - 2s 4ms/sample - loss: 0.0666 - acc: 0.9774 - val_loss: 5.2513 - val_acc: 0.2656
# Epoch 13/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.0534 - acc: 0.9838 - val_loss: 5.8203 - val_acc: 0.2492
# Epoch 14/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.0541 - acc: 0.9855 - val_loss: 6.1536 - val_acc: 0.2557
# Epoch 15/15
# 619/619 [==============================] - 2s 3ms/sample - loss: 0.0386 - acc: 0.9887 - val_loss: 8.2055 - val_acc: 0.2557

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = model.predict(test_data)

test_labels = test_labels.astype('int32')

confusion_matrix = confusion_matrix(test_labels, y_pred.argmax(axis=1))

df_cm = pd.DataFrame(confusion_matrix, index = ['Wake', 'N1', 'N2', 'N3', 'REM'],
                  columns = ['Wake', 'N1', 'N2', 'N3', 'REM'])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)

# %%
y_pred.shape
